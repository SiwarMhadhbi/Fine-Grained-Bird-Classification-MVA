# %% [markdown]
# # <center> Object recognition and computer vision
# # <center> 2021/2022
# # <center> Assignement 3: Image classification
#
# ### Realized by: Siwar Mhadhbi
#
# ---

# %% [markdown]
# In this notebook, we clarify our methodology and the steps we have taken to classify birds and improve the accuracy of our final model.

# %%
# mount the notebook with drive to import data directly

from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1. Data preparation

# %%
path_data = '/content/drive/MyDrive/bird_dataset'
nclasses = 20

# %% [markdown]
# # 1.1. Validation set distribution

# %%
import shutil
import os

for categ in os.listdir(os.path.join(path_data,'train_images')):
  
  path_categ_train = os.path.join(os.path.join(path_data,'train_images'),categ)
  path_categ_val = os.path.join(os.path.join(path_data,'val_images'),categ)

  nbr_training_images = len(os.listdir(path_categ_train))
  nbr_val_images = len(os.listdir(path_categ_val))
  nbr_images_toTransfer = int((nbr_training_images + nbr_val_images) * 0.2 - nbr_val_images)

  if nbr_images_toTransfer > 0 :
    for i,file in enumerate(os.listdir(path_categ_train)):
        shutil.move(os.path.join(path_categ_train,file), os.path.join(path_categ_val,file))
        if i >= nbr_images_toTransfer -1 :
          break

# %% [markdown]
# # 1.2. Crop birds using Faster R-CNN

# %%
import PIL.Image as Image
import torchvision
import torch
import numpy as np
import torchvision.transforms as transforms

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

faster_rcnn = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
faster_rcnn.eval().to(device)

transform = transforms.Compose([
    transforms.ToTensor()
  ])

confidence = 0.7
for dirs in os.listdir(path_data):
    for dir in os.listdir(os.path.join(path_data, dirs)):
      for img in os.listdir(os.path.join(os.path.join(path_data, dirs),dir)):
        path_image = os.path.join(os.path.join(os.path.join(path_data, dirs),dir),img)
        image = Image.open(path_image)
        image = transform(image).to(device)
        im = image.unsqueeze(0)

        outputs = faster_rcnn(im)

        label_birds = 16
        index = None
        if label_birds in outputs[0]['labels'].cpu().numpy():
          index = list(outputs[0]['labels'].cpu().numpy()).index(label_birds)
          max_score_bird = outputs[0]['scores'].detach().cpu().numpy()[index]
          if max_score_bird >= confidence :
            pred_boxes = outputs[0]['boxes'].detach().cpu().numpy()
            bbox = pred_boxes[index].astype(np.int32)
            im = transforms.ToPILImage()(image)
            crop_image = im.crop(bbox)
            crop_image.save(path_image)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
#   0%|          | 0.00/160M [00:00<?, ?B/s]
# "\nfor dirs in os.listdir(path_data):\n    for dir in os.listdir(os.path.join(path_data, dirs)):\n      for img in os.listdir(os.path.join(os.path.join(path_data, dirs),dir)):\n        path_image = os.path.join(os.path.join(os.path.join(path_data, dirs),dir),img)\n        image = Image.open(path_image)\n        image = transform(image).to(device)\n        im = image.unsqueeze(0)\n\n        outputs = faster_rcnn(im)\n\n        label_birds = 16\n        index = None\n        if label_birds in outputs[0]['labels'].cpu().numpy():\n          index = list(outputs[0]['labels'].cpu().numpy()).index(label_birds)\n          max_score_bird = outputs[0]['scores'].detach().cpu().numpy()[index]\n          if max_score_bird >= 0.7 :\n            pred_boxes = outputs[0]['boxes'].detach().cpu().numpy()\n            bbox = pred_boxes[index].astype(np.int32)\n            im = transforms.ToPILImage()(image)\n            crop_image = im.crop(bbox)\n            crop_image.save(path_image)\n"

# %% [markdown]
# # 1.3. Data augmentation

# %%
image_size = 300 
data_transforms = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(30, fill=None),
    transforms.ToTensor(),
    # For normalization
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

data_transforms_test = transforms.Compose([
    transforms.Resize((image_size, image_size)),
    transforms.ToTensor(),
    # For normalization
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# # 2. Modeling

# %% [markdown]
# * Resnet-50
# * VGG-16
# * Densenet-161

# %%
import torch.nn as nn
import torch.nn.functional as F
from torchvision import models
from torch.optim import lr_scheduler

# %% [markdown]
# # 2.1. Model 1. ResNet-50

# %%
model_resnet = models.resnet50(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]

# %%
nbr_layers_tofreeze = 0
for name, child in model_resnet.named_children():
  nbr_layers_tofreeze += 1
  if nbr_layers_tofreeze < 7 :
    for name2, params in child.named_parameters():
      params.requires_grad = False
  else:
    break;

num_ftrs = model_resnet.fc.in_features

n_units = 64
model_resnet.fc = torch.nn.Sequential(
    torch.nn.Linear(num_ftrs, n_units),
    torch.nn.ReLU(),
    torch.nn.Linear(n_units, nclasses)
)

model_resnet.to(device);

# %% [markdown]
# # 2.2. Model 2. VGG-16

# %%
model_vgg = models.vgg16(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
#   0%|          | 0.00/528M [00:00<?, ?B/s]

# %%
nbr_layers_tofreeze = 7
for i,child in enumerate(model_vgg.children()):
  for param in child.parameters():
    param.requires_grad = False
  if i>= nbr_layers_tofreeze:
    break;

num_ftrs = model_vgg.classifier[-1].in_features
model_vgg.classifier[-1] = nn.Linear(num_ftrs, nclasses)

model_vgg.to(device);

# %% [markdown]
# # 2.3. Model 3. DenseNet-161

# %%
model_densenet = models.densenet161(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/densenet161-8d451a50.pth" to /root/.cache/torch/hub/checkpoints/densenet161-8d451a50.pth
#   0%|          | 0.00/110M [00:00<?, ?B/s]

# %%
nbr_layers_tofreeze = 7
for i,child in enumerate(model_densenet.children()):
  for param in child.parameters():
    param.requires_grad = False
  if i>= nbr_layers_tofreeze:
    break;

num_ftrs = model_densenet.classifier.in_features
model_densenet.classifier = nn.Linear(num_ftrs, nclasses)

model_densenet.to(device);

# %% [markdown]
# # 3. Pre-training

# %% [markdown]
# * Batch size : `batch_size = 64`
# * Learning rate : `lr = 0.005`
# * Momentum : `momentum = 0.8`
# * Number of epochs for training : `epochs = 100`

# %%
import torch.optim as optim
from torchvision import datasets

use_cuda = torch.cuda.is_available()
seed = 1
torch.manual_seed(1)

batch_size = 64

train_loader = torch.utils.data.DataLoader(
    datasets.ImageFolder(path_data + '/train_images',
                         transform=data_transforms),
    batch_size=batch_size, shuffle=True, num_workers=1)

val_loader = torch.utils.data.DataLoader(
    datasets.ImageFolder(path_data + '/val_images',
                         transform=data_transforms),
    batch_size=batch_size, shuffle=False, num_workers=1)

# %%
# Neural network

lr = 0.005
momentum = 0.8 
log_interval = 10 
epochs = 100
experiment = 'experiment'

def train(epoch, model,optimizer):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        if use_cuda:
            data, target = data.cuda(), target.cuda()
        optimizer.zero_grad()
        output = model(data)
        criterion = torch.nn.CrossEntropyLoss(reduction='mean')
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data.item()))

def validation(model):
    model.eval()
    validation_loss = 0
    correct = 0
    for data, target in val_loader:
        if use_cuda:
            data, target = data.cuda(), target.cuda()
        output = model(data)
        # sum up batch loss
        criterion = torch.nn.CrossEntropyLoss(reduction='mean')
        validation_loss += criterion(output, target).data.item()
        # get the index of the max log-probability
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()
      
    validation_loss /= len(val_loader.dataset)
    validation_accuracy = correct/len(val_loader.dataset)*100
    print('\nValidation set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)'.format(
        validation_loss, correct, len(val_loader.dataset),
        100. * correct / len(val_loader.dataset)))
    return validation_accuracy

# %% [markdown]
# # 4. Training

# %%
def training(model,name):

    if use_cuda:
        print('Using GPU')
        model.cuda()
    else:
        print('Using CPU')

    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)
    step_lr_scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.8, patience=5, 
                                                       verbose=False)

    for epoch in range(1, epochs + 1):
      train(epoch, model,optimizer)
      validation_accuracy = validation(model)
      step_lr_scheduler.step(validation_accuracy)
      model_file = '/content/drive/MyDrive/Saved_models/' + experiment + '/model_' +name+ str(epoch) + '.pth'
      
      torch.save(model.state_dict(), model_file)
      print('Saved model to ' + model_file + '.\n')

# %% [markdown]
# # 4.1. Training Model 1. ResNet-50

# %%
training(model_resnet,'resnet')
# Out:
# Using GPU
# Train Epoch: 1 [0/955 (0%)]	Loss: 2.990447
# Train Epoch: 1 [640/955 (67%)]	Loss: 2.972745
#
# Validation set: Average loss: 0.0511, Accuracy: 29/230 (13%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet1.pth.
#
# Train Epoch: 2 [0/955 (0%)]	Loss: 2.932184
# Train Epoch: 2 [640/955 (67%)]	Loss: 2.846617
#
# Validation set: Average loss: 0.0487, Accuracy: 74/230 (32%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet2.pth.
#
# Train Epoch: 3 [0/955 (0%)]	Loss: 2.843373
# Train Epoch: 3 [640/955 (67%)]	Loss: 2.565686
#
# Validation set: Average loss: 0.0432, Accuracy: 112/230 (49%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet3.pth.
#
# Train Epoch: 4 [0/955 (0%)]	Loss: 2.439037
# Train Epoch: 4 [640/955 (67%)]	Loss: 2.252784
#
# Validation set: Average loss: 0.0354, Accuracy: 133/230 (58%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet4.pth.
#
# Train Epoch: 5 [0/955 (0%)]	Loss: 2.086045
# Train Epoch: 5 [640/955 (67%)]	Loss: 1.879372
#
# Validation set: Average loss: 0.0280, Accuracy: 145/230 (63%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet5.pth.
#
# Train Epoch: 6 [0/955 (0%)]	Loss: 1.684782
# Train Epoch: 6 [640/955 (67%)]	Loss: 1.352126
#
# Validation set: Average loss: 0.0222, Accuracy: 152/230 (66%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet6.pth.
#
# Train Epoch: 7 [0/955 (0%)]	Loss: 1.200744
# Train Epoch: 7 [640/955 (67%)]	Loss: 1.224649
#
# Validation set: Average loss: 0.0177, Accuracy: 172/230 (75%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet7.pth.
#
# Train Epoch: 8 [0/955 (0%)]	Loss: 0.916464
# Train Epoch: 8 [640/955 (67%)]	Loss: 0.985147
#
# Validation set: Average loss: 0.0154, Accuracy: 174/230 (76%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet8.pth.
#
# Train Epoch: 9 [0/955 (0%)]	Loss: 0.794757
# Train Epoch: 9 [640/955 (67%)]	Loss: 0.708718
#
# Validation set: Average loss: 0.0139, Accuracy: 175/230 (76%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet9.pth.
#
# Train Epoch: 10 [0/955 (0%)]	Loss: 0.554259
# Train Epoch: 10 [640/955 (67%)]	Loss: 0.569126
#
# Validation set: Average loss: 0.0127, Accuracy: 184/230 (80%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet10.pth.
#
# Train Epoch: 11 [0/955 (0%)]	Loss: 0.648482
# Train Epoch: 11 [640/955 (67%)]	Loss: 0.471977
#
# Validation set: Average loss: 0.0114, Accuracy: 188/230 (82%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet11.pth.
#
# Train Epoch: 12 [0/955 (0%)]	Loss: 0.404488
# Train Epoch: 12 [640/955 (67%)]	Loss: 0.551552
#
# Validation set: Average loss: 0.0101, Accuracy: 193/230 (84%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet12.pth.
#
# Train Epoch: 13 [0/955 (0%)]	Loss: 0.358324
# Train Epoch: 13 [640/955 (67%)]	Loss: 0.365021
#
# Validation set: Average loss: 0.0091, Accuracy: 194/230 (84%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet13.pth.
#
# Train Epoch: 14 [0/955 (0%)]	Loss: 0.300014
# Train Epoch: 14 [640/955 (67%)]	Loss: 0.304920
#
# Validation set: Average loss: 0.0089, Accuracy: 195/230 (85%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet14.pth.
#
# Train Epoch: 15 [0/955 (0%)]	Loss: 0.294936
# Train Epoch: 15 [640/955 (67%)]	Loss: 0.306643
#
# Validation set: Average loss: 0.0092, Accuracy: 188/230 (82%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet15.pth.
#
# Train Epoch: 16 [0/955 (0%)]	Loss: 0.181298
# Train Epoch: 16 [640/955 (67%)]	Loss: 0.348979
#
# Validation set: Average loss: 0.0088, Accuracy: 196/230 (85%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet16.pth.
#
# Train Epoch: 17 [0/955 (0%)]	Loss: 0.153623
# Train Epoch: 17 [640/955 (67%)]	Loss: 0.188558
#
# Validation set: Average loss: 0.0086, Accuracy: 196/230 (85%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet17.pth.
#
# Train Epoch: 18 [0/955 (0%)]	Loss: 0.152205
# Train Epoch: 18 [640/955 (67%)]	Loss: 0.142875
#
# Validation set: Average loss: 0.0083, Accuracy: 195/230 (85%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet18.pth.
#
# Train Epoch: 19 [0/955 (0%)]	Loss: 0.140684
# Train Epoch: 19 [640/955 (67%)]	Loss: 0.116386
#
# Validation set: Average loss: 0.0081, Accuracy: 193/230 (84%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet19.pth.
#
# Train Epoch: 20 [0/955 (0%)]	Loss: 0.103848
# Train Epoch: 20 [640/955 (67%)]	Loss: 0.179099
#
# Validation set: Average loss: 0.0080, Accuracy: 197/230 (86%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet20.pth.
#
# Train Epoch: 21 [0/955 (0%)]	Loss: 0.101436
# Train Epoch: 21 [640/955 (67%)]	Loss: 0.094824
#
# Validation set: Average loss: 0.0081, Accuracy: 192/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet21.pth.
#
# Train Epoch: 22 [0/955 (0%)]	Loss: 0.089102
# Train Epoch: 22 [640/955 (67%)]	Loss: 0.069793
#
# Validation set: Average loss: 0.0082, Accuracy: 193/230 (84%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet22.pth.
#
# Train Epoch: 23 [0/955 (0%)]	Loss: 0.121262
# Train Epoch: 23 [640/955 (67%)]	Loss: 0.053198
#
# Validation set: Average loss: 0.0083, Accuracy: 193/230 (84%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet23.pth.
#
# Train Epoch: 24 [0/955 (0%)]	Loss: 0.062196
# Train Epoch: 24 [640/955 (67%)]	Loss: 0.053158
#
# Validation set: Average loss: 0.0086, Accuracy: 196/230 (85%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet24.pth.
#
# Train Epoch: 25 [0/955 (0%)]	Loss: 0.053165
# Train Epoch: 25 [640/955 (67%)]	Loss: 0.067494
#
# Validation set: Average loss: 0.0093, Accuracy: 191/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet25.pth.
#
# Train Epoch: 26 [0/955 (0%)]	Loss: 0.042778
# Train Epoch: 26 [640/955 (67%)]	Loss: 0.070598
#
# Validation set: Average loss: 0.0089, Accuracy: 194/230 (84%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet26.pth.
#
# Train Epoch: 27 [0/955 (0%)]	Loss: 0.043633
# Train Epoch: 27 [640/955 (67%)]	Loss: 0.042661
#
# Validation set: Average loss: 0.0080, Accuracy: 195/230 (85%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet27.pth.
#
# Train Epoch: 28 [0/955 (0%)]	Loss: 0.037268
# Train Epoch: 28 [640/955 (67%)]	Loss: 0.034696
#
# Validation set: Average loss: 0.0076, Accuracy: 196/230 (85%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet28.pth.
#
# Train Epoch: 29 [0/955 (0%)]	Loss: 0.046946
# Train Epoch: 29 [640/955 (67%)]	Loss: 0.050729
#
# Validation set: Average loss: 0.0082, Accuracy: 192/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet29.pth.
#
# Train Epoch: 30 [0/955 (0%)]	Loss: 0.043631
# Train Epoch: 30 [640/955 (67%)]	Loss: 0.038016
#
# Validation set: Average loss: 0.0080, Accuracy: 198/230 (86%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet30.pth.
#
# Train Epoch: 31 [0/955 (0%)]	Loss: 0.023949
# Train Epoch: 31 [640/955 (67%)]	Loss: 0.037909
#
# Validation set: Average loss: 0.0084, Accuracy: 193/230 (84%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet31.pth.
#
# Train Epoch: 32 [0/955 (0%)]	Loss: 0.028465
# Train Epoch: 32 [640/955 (67%)]	Loss: 0.017639
#
# Validation set: Average loss: 0.0081, Accuracy: 195/230 (85%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet32.pth.
#
# Train Epoch: 33 [0/955 (0%)]	Loss: 0.051243
# Train Epoch: 33 [640/955 (67%)]	Loss: 0.018733
#
# Validation set: Average loss: 0.0086, Accuracy: 195/230 (85%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet33.pth.
#
# Train Epoch: 34 [0/955 (0%)]	Loss: 0.037624
# Train Epoch: 34 [640/955 (67%)]	Loss: 0.018831
#
# Validation set: Average loss: 0.0078, Accuracy: 198/230 (86%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet34.pth.
#
# Train Epoch: 35 [0/955 (0%)]	Loss: 0.032018
# Train Epoch: 35 [640/955 (67%)]	Loss: 0.033381
#
# Validation set: Average loss: 0.0087, Accuracy: 192/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resn
)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet50.pth.
#
# Train Epoch: 51 [0/955 (0%)]	Loss: 0.011182
# Train Epoch: 51 [640/955 (67%)]	Loss: 0.009182
#
# Validation set: Average loss: 0.0082, Accuracy: 195/230 (85%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet51.pth.
#
# Train Epoch: 52 [0/955 (0%)]	Loss: 0.011520
# Train Epoch: 52 [640/955 (67%)]	Loss: 0.006753
#
# Validation set: Average loss: 0.0090, Accuracy: 190/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet52.pth.
#
# Train Epoch: 53 [0/955 (0%)]	Loss: 0.042957
# Train Epoch: 53 [640/955 (67%)]	Loss: 0.007603
#
# Validation set: Average loss: 0.0090, Accuracy: 196/230 (85%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet53.pth.
#
# Train Epoch: 54 [0/955 (0%)]	Loss: 0.006514
# Train Epoch: 54 [640/955 (67%)]	Loss: 0.017519
#
# Validation set: Average loss: 0.0090, Accuracy: 195/230 (85%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet54.pth.
#
# Train Epoch: 55 [0/955 (0%)]	Loss: 0.008610
# Train Epoch: 55 [640/955 (67%)]	Loss: 0.010812
#
# Validation set: Average loss: 0.0085, Accuracy: 196/230 (85%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet55.pth.
#
# Train Epoch: 56 [0/955 (0%)]	Loss: 0.007140
# Train Epoch: 56 [640/955 (67%)]	Loss: 0.007740
#
# Validation set: Average loss: 0.0085, Accuracy: 193/230 (84%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet56.pth.
#
# Train Epoch: 57 [0/955 (0%)]	Loss: 0.010426
# Train Epoch: 57 [640/955 (67%)]	Loss: 0.011227
#
# Validation set: Average loss: 0.0083, Accuracy: 197/230 (86%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet57.pth.
#
# Train Epoch: 58 [0/955 (0%)]	Loss: 0.008475
# Train Epoch: 58 [640/955 (67%)]	Loss: 0.007922
#
# Validation set: Average loss: 0.0087, Accuracy: 197/230 (86%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet58.pth.
#
# Train Epoch: 59 [0/955 (0%)]	Loss: 0.010277
# Train Epoch: 59 [640/955 (67%)]	Loss: 0.007752
#
# Validation set: Average loss: 0.0089, Accuracy: 195/230 (85%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet59.pth.
#
# Train Epoch: 60 [0/955 (0%)]	Loss: 0.005300
# Train Epoch: 60 [640/955 (67%)]	Loss: 0.007617
#
# Validation set: Average loss: 0.0075, Accuracy: 197/230 (86%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet60.pth.
#
# Train Epoch: 61 [0/955 (0%)]	Loss: 0.005268
# Train Epoch: 61 [640/955 (67%)]	Loss: 0.011341
#
# Validation set: Average loss: 0.0098, Accuracy: 197/230 (86%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet61.pth.
#
# Train Epoch: 62 [0/955 (0%)]	Loss: 0.008778
# Train Epoch: 62 [640/955 (67%)]	Loss: 0.010920
#
# Validation set: Average loss: 0.0093, Accuracy: 195/230 (85%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet62.pth.
#
# Train Epoch: 63 [0/955 (0%)]	Loss: 0.006848
# Train Epoch: 63 [640/955 (67%)]	Loss: 0.005798
#
# Validation set: Average loss: 0.0093, Accuracy: 192/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet63.pth.
#
# Train Epoch: 64 [0/955 (0%)]	Loss: 0.009070
# Train Epoch: 64 [640/955 (67%)]	Loss: 0.016706
#
# Validation set: Average loss: 0.0084, Accuracy: 197/230 (86%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet64.pth.
#
# Train Epoch: 65 [0/955 (0%)]	Loss: 0.005574
# Train Epoch: 65 [640/955 (67%)]	Loss: 0.012403
#
# Validation set: Average loss: 0.0095, Accuracy: 196/230 (85%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet65.pth.
#
# Train Epoch: 66 [0/955 (0%)]	Loss: 0.006324
# Train Epoch: 66 [640/955 (67%)]	Loss: 0.004927
#
# Validation set: Average loss: 0.0091, Accuracy: 198/230 (86%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resn
Accuracy: 193/230 (84%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet98.pth.
#
# Train Epoch: 99 [0/955 (0%)]	Loss: 0.032755
# Train Epoch: 99 [640/955 (67%)]	Loss: 0.007209
#
# Validation set: Average loss: 0.0092, Accuracy: 194/230 (84%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet99.pth.
#
# Train Epoch: 100 [0/955 (0%)]	Loss: 0.005115
# Train Epoch: 100 [640/955 (67%)]	Loss: 0.006170
#
# Validation set: Average loss: 0.0097, Accuracy: 197/230 (86%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_resnet100.pth.

# %% [markdown]
# # 4.2. Training Model 2. VGG-16

# %%
training(model_vgg,'vgg')
# Out:
# Using GPU
# Train Epoch: 1 [0/955 (0%)]	Loss: 3.092148
# Train Epoch: 1 [640/955 (67%)]	Loss: 2.306087
#
# Validation set: Average loss: 0.0327, Accuracy: 124/230 (54%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg1.pth.
#
# Train Epoch: 2 [0/955 (0%)]	Loss: 1.843766
# Train Epoch: 2 [640/955 (67%)]	Loss: 1.606452
#
# Validation set: Average loss: 0.0228, Accuracy: 157/230 (68%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg2.pth.
#
# Train Epoch: 3 [0/955 (0%)]	Loss: 1.226636
# Train Epoch: 3 [640/955 (67%)]	Loss: 0.944987
#
# Validation set: Average loss: 0.0199, Accuracy: 157/230 (68%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg3.pth.
#
# Train Epoch: 4 [0/955 (0%)]	Loss: 1.137595
# Train Epoch: 4 [640/955 (67%)]	Loss: 1.207218
#
# Validation set: Average loss: 0.0180, Accuracy: 169/230 (73%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg4.pth.
#
# Train Epoch: 5 [0/955 (0%)]	Loss: 0.974344
# Train Epoch: 5 [640/955 (67%)]	Loss: 0.984292
#
# Validation set: Average loss: 0.0179, Accuracy: 166/230 (72%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg5.pth.
#
# Train Epoch: 6 [0/955 (0%)]	Loss: 0.890392
# Train Epoch: 6 [640/955 (67%)]	Loss: 0.886950
#
# Validation set: Average loss: 0.0165, Accuracy: 171/230 (74%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg6.pth.
#
# Train Epoch: 7 [0/955 (0%)]	Loss: 0.946693
# Train Epoch: 7 [640/955 (67%)]	Loss: 0.884754
#
# Validation set: Average loss: 0.0154, Accuracy: 167/230 (73%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg7.pth.
#
# Train Epoch: 8 [0/955 (0%)]	Loss: 0.927880
# Train Epoch: 8 [640/955 (67%)]	Loss: 1.029548
#
# Validation set: Average loss: 0.0151, Accuracy: 176/230 (77%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg8.pth.
#
# Train Epoch: 9 [0/955 (0%)]	Loss: 0.918954
# Train Epoch: 9 [640/955 (67%)]	Loss: 0.870469
#
# Validation set: Average loss: 0.0146, Accuracy: 177/230 (77%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg9.pth.
#
# Train Epoch: 10 [0/955 (0%)]	Loss: 0.804696
# Train Epoch: 10 [640/955 (67%)]	Loss: 0.974149
#
# Validation set: Average loss: 0.0136, Accuracy: 176/230 (77%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg10.pth.
#
# Train Epoch: 11 [0/955 (0%)]	Loss: 0.856406
# Train Epoch: 11 [640/955 (67%)]	Loss: 0.617549
#
# Validation set: Average loss: 0.0141, Accuracy: 173/230 (75%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg11.pth.
#
# Train Epoch: 12 [0/955 (0%)]	Loss: 0.727716
# Train Epoch: 12 [640/955 (67%)]	Loss: 0.844692
#
# Validation set: Average loss: 0.0147, Accuracy: 172/230 (75%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vg
230 (76%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg86.pth.
#
# Train Epoch: 87 [0/955 (0%)]	Loss: 0.598249
# Train Epoch: 87 [640/955 (67%)]	Loss: 0.540595
#
# Validation set: Average loss: 0.0122, Accuracy: 178/230 (77%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg87.pth.
#
# Train Epoch: 88 [0/955 (0%)]	Loss: 0.597970
# Train Epoch: 88 [640/955 (67%)]	Loss: 0.602922
#
# Validation set: Average loss: 0.0124, Accuracy: 179/230 (78%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg88.pth.
#
# Train Epoch: 89 [0/955 (0%)]	Loss: 0.371232
# Train Epoch: 89 [640/955 (67%)]	Loss: 0.765061
#
# Validation set: Average loss: 0.0135, Accuracy: 168/230 (73%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg89.pth.
#
# Train Epoch: 90 [0/955 (0%)]	Loss: 0.580142
# Train Epoch: 90 [640/955 (67%)]	Loss: 0.504766
#
# Validation set: Average loss: 0.0120, Accuracy: 176/230 (77%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg90.pth.
#
# Train Epoch: 91 [0/955 (0%)]	Loss: 0.480823
# Train Epoch: 91 [640/955 (67%)]	Loss: 0.380040
#
# Validation set: Average loss: 0.0124, Accuracy: 179/230 (78%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg91.pth.
#
# Train Epoch: 92 [0/955 (0%)]	Loss: 0.426822
# Train Epoch: 92 [640/955 (67%)]	Loss: 0.444246
#
# Validation set: Average loss: 0.0125, Accuracy: 173/230 (75%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg92.pth.
#
# Train Epoch: 93 [0/955 (0%)]	Loss: 0.403115
# Train Epoch: 93 [640/955 (67%)]	Loss: 0.511617
#
# Validation set: Average loss: 0.0120, Accuracy: 176/230 (77%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg93.pth.
#
# Train Epoch: 94 [0/955 (0%)]	Loss: 0.611684
# Train Epoch: 94 [640/955 (67%)]	Loss: 0.518150
#
# Validation set: Average loss: 0.0127, Accuracy: 172/230 (75%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg94.pth.
#
# Train Epoch: 95 [0/955 (0%)]	Loss: 0.397915
# Train Epoch: 95 [640/955 (67%)]	Loss: 0.473597
#
# Validation set: Average loss: 0.0126, Accuracy: 175/230 (76%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg95.pth.
#
# Train Epoch: 96 [0/955 (0%)]	Loss: 0.526819
# Train Epoch: 96 [640/955 (67%)]	Loss: 0.509708
#
# Validation set: Average loss: 0.0128, Accuracy: 172/230 (75%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg96.pth.
#
# Train Epoch: 97 [0/955 (0%)]	Loss: 0.395949
# Train Epoch: 97 [640/955 (67%)]	Loss: 0.520694
#
# Validation set: Average loss: 0.0122, Accuracy: 178/230 (77%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg97.pth.
#
# Train Epoch: 98 [0/955 (0%)]	Loss: 0.402200
# Train Epoch: 98 [640/955 (67%)]	Loss: 0.500671
#
# Validation set: Average loss: 0.0132, Accuracy: 175/230 (76%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg98.pth.
#
# Train Epoch: 99 [0/955 (0%)]	Loss: 0.577983
# Train Epoch: 99 [640/955 (67%)]	Loss: 0.559439
#
# Validation set: Average loss: 0.0119, Accuracy: 176/230 (77%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg99.pth.
#
# Train Epoch: 100 [0/955 (0%)]	Loss: 0.499755
# Train Epoch: 100 [640/955 (67%)]	Loss: 0.744308
#
# Validation set: Average loss: 0.0127, Accuracy: 177/230 (77%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_vgg100.pth.

# %% [markdown]
# # 4.3. Training Model 3. DenseNet-161

# %%
training(model_densenet,'densenet')
# Out:
# Using GPU
# Train Epoch: 1 [0/955 (0%)]	Loss: 3.044427
# Train Epoch: 1 [640/955 (67%)]	Loss: 2.851615
#
# Validation set: Average loss: 0.0455, Accuracy: 74/230 (32%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet1.pth.
#
# Train Epoch: 2 [0/955 (0%)]	Loss: 2.563597
# Train Epoch: 2 [640/955 (67%)]	Loss: 2.309414
#
# Validation set: Average loss: 0.0376, Accuracy: 128/230 (56%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet2.pth.
#
# Train Epoch: 3 [0/955 (0%)]	Loss: 2.276135
# Train Epoch: 3 [640/955 (67%)]	Loss: 1.907945
#
# Validation set: Average loss: 0.0323, Accuracy: 149/230 (65%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet3.pth.
#
# Train Epoch: 4 [0/955 (0%)]	Loss: 1.848916
# Train Epoch: 4 [640/955 (67%)]	Loss: 1.533406
#
# Validation set: Average loss: 0.0274, Accuracy: 164/230 (71%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet4.pth.
#
# Train Epoch: 5 [0/955 (0%)]	Loss: 1.328777
# Train Epoch: 5 [640/955 (67%)]	Loss: 1.318672
#
# Validation set: Average loss: 0.0245, Accuracy: 165/230 (72%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet5.pth.
#
# Train Epoch: 6 [0/955 (0%)]	Loss: 1.346433
# Train Epoch: 6 [640/955 (67%)]	Loss: 1.169212
#
# Validation set: Average loss: 0.0218, Accuracy: 178/230 (77%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet6.pth.
#
# Train Epoch: 7 [0/955 (0%)]	Loss: 1.243071
# Train Epoch: 7 [640/955 (67%)]	Loss: 1.020729
#
# Validation set: Average loss: 0.0206, Accuracy: 176/230 (77%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet7.pth.
#
# Train Epoch: 8 [0/955 (0%)]	Loss: 1.019581
# Train Epoch: 8 [640/955 (67%)]	Loss: 0.921866
#
# Validation set: Average loss: 0.0196, Accuracy: 176/230 (77%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet8.pth.
#
# Train Epoch: 9 [0/955 (0%)]	Loss: 1.001884
# Train Epoch: 9 [640/955 (67%)]	Loss: 1.021723
#
# Validation set: Average loss: 0.0181, Accuracy: 185/230 (80%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet9.pth.
#
# Train Epoch: 10 [0/955 (0%)]	Loss: 0.924145
# Train Epoch: 10 [640/955 (67%)]	Loss: 0.889820
#
# Validation set: Average loss: 0.0173, Accuracy: 181/230 (79%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet10.pth.
#
# Train Epoch: 11 [0/955 (0%)]	Loss: 0.807453
# Train Epoch: 11 [640/955 (67%)]	Loss: 0.786960
#
# Validation set: Average loss: 0.0166, Accuracy: 181/230 (79%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet11.pth.
#
# Train Epoch: 12 [0/955 (0%)]	Loss: 0.777148
# Train Epoch: 12 [640/955 (67%)]	Loss: 0.772204
#
# Validation set: Average loss: 0.0157, Accuracy: 182/230 (79%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet12.pth.
#
# Train Epoch: 13 [0/955 (0%)]	Loss: 0.591765
# Train Epoch: 13 [640/955 (67%)]	Loss: 0.727931
#
# Validation set: Average loss: 0.0148, Accuracy: 189/230 (82%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet13.pth.
#
# Train Epoch: 14 [0/955 (0%)]	Loss: 0.712797
# Train Epoch: 14 [640/955 (67%)]	Loss: 0.625245
#
# Validation set: Average loss: 0.0148, Accuracy: 189/230 (82%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet14.pth.
#
# Train Epoch: 15 [0/955 (0%)]	Loss: 0.627566
# Train Epoch: 15 [640/955 (67%)]	Loss: 0.717997
#
# Validation set: Average loss: 0.0142, Accuracy: 189/230 (82%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet15.pth.
#
# Train Epoch: 16 [0/955 (0%)]	Loss: 0.605564
# Train Epoch: 16 [640/955 (67%)]	Loss: 0.612220
#
# Validation set: Average loss: 0.0138, Accuracy: 189/230 (82%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet16.pth.
#
# Train Epoch: 17 [0/955 (0%)]	Loss: 0.650240
# Train Epoch: 17 [640/955 (67%)]	Loss: 0.512206
#
# Validation set: Average loss: 0.0134, Accuracy: 186/230 (81%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet17.pth.
#
# Train Epoch: 18 [0/955 (0%)]	Loss: 0.637774
# Train Epoch: 18 [640/955 (67%)]	Loss: 0.584156
#
# Validation set: Average loss: 0.0129, Accuracy: 189/230 (82%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet18.pth.
#
# Train Epoch: 19 [0/955 (0%)]	Loss: 0.544013
# Train Epoch: 19 [640/955 (67%)]	Loss: 0.573561
#
# Validation set: Average loss: 0.0126, Accuracy: 191/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet19.pth.
#
# Train Epoch: 20 [0/955 (0%)]	Loss: 0.532790
# Train Epoch: 20 [640/955 (67%)]	Loss: 0.624905
#
# Validation set: Average loss: 0.0126, Accuracy: 188/230 (82%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet20.pth.
#
# Train Epoch: 21 [0/955 (0%)]	Loss: 0.583453
# Train Epoch: 21 [640/955 (67%)]	Loss: 0.538828
#
# Validation set: Average loss: 0.0127, Accuracy: 185/230 (80%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet21.pth.
#
# Train Epoch: 22 [0/955 (0%)]	Loss: 0.560269
# Train Epoch: 22 [640/955 (67%)]	Loss: 0.483922
#
# Validation set: Average loss: 0.0123, Accuracy: 192/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet22.pth.
#
# Train Epoch: 23 [0/955 (0%)]	Loss: 0.597918
# Train Epoch: 23 [640/955 (67%)]	Loss: 0.464847
#
# Validation set: Average loss: 0.0124, Accuracy: 184/230 (80%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet23.pth.
#
# Train Epoch: 24 [0/955 (0%)]	Loss: 0.371343
# Train Epoch: 24 [640/955 (67%)]	Loss: 0.409920
#
# Validation set: Average loss: 0.0121, Accuracy: 189/230 (82%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet24.pth.
#
# Train Epoch: 25 [0/955 (0%)]	Loss: 0.478053
# Train Epoch: 25 [640/955 (67%)]	Loss: 0.384297
#
# Validation set: Average loss: 0.0114, Accuracy: 185/230 (80%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet25.pth.
#
# Train Epoch: 26 [0/955 (0%)]	Loss: 0.512562
# Train Epoch: 26 [640/955 (67%)]	Loss: 0.478272
#
# Validation set: Average loss: 0.0112, Accuracy: 193/230 (84%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet26.pth.
#
# Train Epoch: 27 [0/955 (0%)]	Loss: 0.476804
# Train Epoch: 27 [640/955 (67%)]	Loss: 0.337108
#
# Validation set: Average loss: 0.0116, Accuracy: 191/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet27.pth.
#
# Train Epoch: 28 [0/955 (0%)]	Loss: 0.486566
# Train Epoch: 28 [640/955 (67%)]	Loss: 0.336127
#
# Validation set: Average loss: 0.0112, Accuracy: 191/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet28.pth.
#
# Train Epoch: 29 [0/955 (0%)]	Loss: 0.557713
# Train Epoch: 29 [640/955 (67%)]	Loss: 0.425433
#
# Validation set: Average loss: 0.0115, Accuracy: 188/230 (82%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet29.pth.
#
# Train Epoch: 30 [0/955 (0%)]	Loss: 0.336711
# Train Epoch: 30 [640/955 (67%)]	Loss: 0.415583
#
# Validation set: Average loss: 0.0115, Accuracy: 190/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet30.pth.
#
# Train Epoch: 31 [0/955 (0%)]	Loss: 0.399927
# Train Epoch: 31 [640/955 (67%)]	Loss: 0.364782
#
# Validation set: Average loss: 0.0119, Accuracy: 182/230 (79%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densen
Accuracy: 196/230 (85%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet47.pth.
#
# Train Epoch: 48 [0/955 (0%)]	Loss: 0.405952
# Train Epoch: 48 [640/955 (67%)]	Loss: 0.246415
#
# Validation set: Average loss: 0.0106, Accuracy: 191/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet48.pth.
#
# Train Epoch: 49 [0/955 (0%)]	Loss: 0.302514
# Train Epoch: 49 [640/955 (67%)]	Loss: 0.269333
#
# Validation set: Average loss: 0.0107, Accuracy: 191/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet49.pth.
#
# Train Epoch: 50 [0/955 (0%)]	Loss: 0.290113
# Train Epoch: 50 [640/955 (67%)]	Loss: 0.237721
#
# Validation set: Average loss: 0.0102, Accuracy: 190/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet50.pth.
#
# Train Epoch: 51 [0/955 (0%)]	Loss: 0.264444
# Train Epoch: 51 [640/955 (67%)]	Loss: 0.284197
#
# Validation set: Average loss: 0.0097, Accuracy: 191/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet51.pth.
#
# Train Epoch: 52 [0/955 (0%)]	Loss: 0.171105
# Train Epoch: 52 [640/955 (67%)]	Loss: 0.228674
#
# Validation set: Average loss: 0.0099, Accuracy: 190/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet52.pth.
#
# Train Epoch: 53 [0/955 (0%)]	Loss: 0.324718
# Train Epoch: 53 [640/955 (67%)]	Loss: 0.294940
#
# Validation set: Average loss: 0.0104, Accuracy: 190/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet53.pth.
#
# Train Epoch: 54 [0/955 (0%)]	Loss: 0.257641
# Train Epoch: 54 [640/955 (67%)]	Loss: 0.251772
#
# Validation set: Average loss: 0.0097, Accuracy: 195/230 (85%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet54.pth.
#
# Train Epoch: 55 [0/955 (0%)]	Loss: 0.404608
# Train Epoch: 55 [640/955 (67%)]	Loss: 0.251723
#
# Validation set: Average loss: 0.0109, Accuracy: 188/230 (82%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet55.pth.
#
# Train Epoch: 56 [0/955 (0%)]	Loss: 0.295146
# Train Epoch: 56 [640/955 (67%)]	Loss: 0.215956
#
# Validation set: Average loss: 0.0101, Accuracy: 189/230 (82%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet56.pth.
#
# Train Epoch: 57 [0/955 (0%)]	Loss: 0.280134
# Train Epoch: 57 [640/955 (67%)]	Loss: 0.293534
#
# Validation set: Average loss: 0.0091, Accuracy: 193/230 (84%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet57.pth.
#
# Train Epoch: 58 [0/955 (0%)]	Loss: 0.336090
# Train Epoch: 58 [640/955 (67%)]	Loss: 0.270876
#
# Validation set: Average loss: 0.0097, Accuracy: 194/230 (84%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet58.pth.
#
# Train Epoch: 59 [0/955 (0%)]	Loss: 0.266488
# Train Epoch: 59 [640/955 (67%)]	Loss: 0.356427
#
# Validation set: Average loss: 0.0103, Accuracy: 186/230 (81%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet59.pth.
#
# Train Epoch: 60 [0/955 (0%)]	Loss: 0.215447
# Train Epoch: 60 [640/955 (67%)]	Loss: 0.345476
#
# Validation set: Average loss: 0.0101, Accuracy: 190/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet60.pth.
#
# Train Epoch: 61 [0/955 (0%)]	Loss: 0.257112
# Train Epoch: 61 [640/955 (67%)]	Loss: 0.363631
#
# Validation set: Average loss: 0.0104, Accuracy: 191/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet61.pth.
#
# Train Epoch: 62 [0/955 (0%)]	Loss: 0.314779
# Train Epoch: 62 [640/955 (67%)]	Loss: 0.182306
#
# Validation set: Average loss: 0.0097, Accuracy: 189/230 (82%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet62.pth.
#
# Train Epoch: 63 [0/955 (0%)]	Loss: 0.259791
# Train Epoch: 63 [640/955 (67%)]	Loss: 0.297925
#
# Validation set: Average loss: 0.0101, Accuracy: 191/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densen
Accuracy: 193/230 (84%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet78.pth.
#
# Train Epoch: 79 [0/955 (0%)]	Loss: 0.188316
# Train Epoch: 79 [640/955 (67%)]	Loss: 0.257037
#
# Validation set: Average loss: 0.0097, Accuracy: 186/230 (81%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet79.pth.
#
# Train Epoch: 80 [0/955 (0%)]	Loss: 0.226036
# Train Epoch: 80 [640/955 (67%)]	Loss: 0.188821
#
# Validation set: Average loss: 0.0098, Accuracy: 196/230 (85%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet80.pth.
#
# Train Epoch: 81 [0/955 (0%)]	Loss: 0.270034
# Train Epoch: 81 [640/955 (67%)]	Loss: 0.382008
#
# Validation set: Average loss: 0.0102, Accuracy: 191/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet81.pth.
#
# Train Epoch: 82 [0/955 (0%)]	Loss: 0.251542
# Train Epoch: 82 [640/955 (67%)]	Loss: 0.213187
#
# Validation set: Average loss: 0.0100, Accuracy: 193/230 (84%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet82.pth.
#
# Train Epoch: 83 [0/955 (0%)]	Loss: 0.252396
# Train Epoch: 83 [640/955 (67%)]	Loss: 0.239424
#
# Validation set: Average loss: 0.0103, Accuracy: 189/230 (82%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet83.pth.
#
# Train Epoch: 84 [0/955 (0%)]	Loss: 0.232106
# Train Epoch: 84 [640/955 (67%)]	Loss: 0.223879
#
# Validation set: Average loss: 0.0097, Accuracy: 192/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet84.pth.
#
# Train Epoch: 85 [0/955 (0%)]	Loss: 0.253200
# Train Epoch: 85 [640/955 (67%)]	Loss: 0.281611
#
# Validation set: Average loss: 0.0103, Accuracy: 190/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet85.pth.
#
# Train Epoch: 86 [0/955 (0%)]	Loss: 0.174650
# Train Epoch: 86 [640/955 (67%)]	Loss: 0.231076
#
# Validation set: Average loss: 0.0103, Accuracy: 188/230 (82%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet86.pth.
#
# Train Epoch: 87 [0/955 (0%)]	Loss: 0.318978
# Train Epoch: 87 [640/955 (67%)]	Loss: 0.282752
#
# Validation set: Average loss: 0.0099, Accuracy: 188/230 (82%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet87.pth.
#
# Train Epoch: 88 [0/955 (0%)]	Loss: 0.207138
# Train Epoch: 88 [640/955 (67%)]	Loss: 0.257141
#
# Validation set: Average loss: 0.0097, Accuracy: 190/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet88.pth.
#
# Train Epoch: 89 [0/955 (0%)]	Loss: 0.256112
# Train Epoch: 89 [640/955 (67%)]	Loss: 0.217890
#
# Validation set: Average loss: 0.0100, Accuracy: 192/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet89.pth.
#
# Train Epoch: 90 [0/955 (0%)]	Loss: 0.217800
# Train Epoch: 90 [640/955 (67%)]	Loss: 0.343361
#
# Validation set: Average loss: 0.0104, Accuracy: 186/230 (81%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet90.pth.
#
# Train Epoch: 91 [0/955 (0%)]	Loss: 0.279622
# Train Epoch: 91 [640/955 (67%)]	Loss: 0.418920
#
# Validation set: Average loss: 0.0104, Accuracy: 185/230 (80%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet91.pth.
#
# Train Epoch: 92 [0/955 (0%)]	Loss: 0.271452
# Train Epoch: 92 [640/955 (67%)]	Loss: 0.201724
#
# Validation set: Average loss: 0.0093, Accuracy: 194/230 (84%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet92.pth.
#
# Train Epoch: 93 [0/955 (0%)]	Loss: 0.227996
# Train Epoch: 93 [640/955 (67%)]	Loss: 0.222253
#
# Validation set: Average loss: 0.0095, Accuracy: 189/230 (82%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet93.pth.
#
# Train Epoch: 94 [0/955 (0%)]	Loss: 0.234904
# Train Epoch: 94 [640/955 (67%)]	Loss: 0.153389
#
# Validation set: Average loss: 0.0098, Accuracy: 192/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet94.pth.
#
# Train Epoch: 95 [0/955 (0%)]	Loss: 0.217569
# Train Epoch: 95 [640/955 (67%)]	Loss: 0.289845
#
# Validation set: Average loss: 0.0095, Accuracy: 191/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet95.pth.
#
# Train Epoch: 96 [0/955 (0%)]	Loss: 0.289284
# Train Epoch: 96 [640/955 (67%)]	Loss: 0.207137
#
# Validation set: Average loss: 0.0101, Accuracy: 190/230 (83%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet96.pth.
#
# Train Epoch: 97 [0/955 (0%)]	Loss: 0.232130
# Train Epoch: 97 [640/955 (67%)]	Loss: 0.249102
#
# Validation set: Average loss: 0.0103, Accuracy: 189/230 (82%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet97.pth.
#
# Train Epoch: 98 [0/955 (0%)]	Loss: 0.203688
# Train Epoch: 98 [640/955 (67%)]	Loss: 0.212905
#
# Validation set: Average loss: 0.0097, Accuracy: 197/230 (86%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet98.pth.
#
# Train Epoch: 99 [0/955 (0%)]	Loss: 0.255930
# Train Epoch: 99 [640/955 (67%)]	Loss: 0.281515
#
# Validation set: Average loss: 0.0093, Accuracy: 193/230 (84%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet99.pth.
#
# Train Epoch: 100 [0/955 (0%)]	Loss: 0.261426
# Train Epoch: 100 [640/955 (67%)]	Loss: 0.221410
#
# Validation set: Average loss: 0.0097, Accuracy: 189/230 (82%)
# Saved model to /content/drive/MyDrive/Saved_models/experiment/model_densenet100.pth.

# %% [markdown]
# # 5. Evaluation

# %%
from tqdm import tqdm

use_cuda = torch.cuda.is_available()

nn_models = [model_resnet, model_densenet] # ,model_vgg]#
name_models = ['resnet93','densenet68'] # ,'vgg51']
for i,model in enumerate(nn_models): 
  model_file = '/content/drive/MyDrive/Saved_models/' + experiment + '/model_' +name_models[i]+  '.pth' 
  state_dict = torch.load(model_file)
  model.load_state_dict(state_dict)
  model.eval()

  if use_cuda:
      print('Using GPU')
      model.cuda()
  else:
      print('Using CPU')

test_dir = path_data + '/test_images/mistery_category'

def pil_loader(path):
    # open path as file to avoid ResourceWarning (https://github.com/python-pillow/Pillow/issues/835)
    with open(path, 'rb') as f:
        with Image.open(f) as img:
            return img.convert('RGB')

outfile =  '/content/drive/MyDrive/Saved_models/' + 'experiment/kaggle.csv'
output_file = open(outfile, "w")
output_file.write("Id,Category\n")
for f in tqdm(os.listdir(test_dir)):
    if 'jpg' in f:
        data = data_transforms_test(pil_loader(test_dir + '/' + f))
        data = data.view(1, data.size(0), data.size(1), data.size(2))
        if use_cuda:
            data = data.cuda()

        output = 0.6 * model_resnet(data) +  0.4 * model_densenet(data)
        
        pred = output.data.max(1, keepdim=True)[1]
        output_file.write("%s,%d\n" % (f[:-4], pred))

output_file.close()

print("Succesfully wrote " + outfile + ', you can upload this file to the kaggle competition website')
# Out:
# Using GPU
# Using GPU
# 100%|██████████| 517/517 [01:28<00:00,  5.84it/s]
# Succesfully wrote /content/drive/MyDrive/Saved_models/experiment/kaggle.csv, you can upload this file to the kaggle competition website
